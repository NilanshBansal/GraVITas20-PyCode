# %%
import numpy as np
from PIL import Image

# %%
photo = np.array(Image.open('towers.jpeg'))

# %%
type(photo)
# Out:
# numpy.ndarray

# %%
photo.shape
# Out:
# (333, 500, 3)

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(photo)

# %%
plt.imshow(photo[::-1])

# %%
plt.imshow(photo[:,::-1])

# %%
plt.imshow(photo[100:250,100:200])

# %%
plt.imshow(photo[:,200:400])

# %%
photo_masked = np.where(photo>100, 255, 0)

# %%
plt.imshow(photo_masked)

# %%
photo_transposed = photo[:,:,0].T

# %%
plt.imshow(photo_transposed)
